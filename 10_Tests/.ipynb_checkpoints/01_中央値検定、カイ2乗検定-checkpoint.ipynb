# %% [markdown]
# ## 中央値検定(メディアン検定)

# %% [markdown]
# 2標本それぞれについてmより大きい（もしくはm以上の）データの件数とm以下（もしくはm未満）のデータの件数を求め、2行×2列の分割表を作成する。この分割表に対してカイ二乗検定を行い、2標本の分布が独立かどうかを検定する。

# %% [markdown]
# ## χ二乗検定

# %% [markdown]
# 比較したい事象に対する頻度の検定。
# 2つの間に差がない帰無仮説を立てて検証する。

# %% [raw]
# データをクロス集計表にまとめる
# 期待度数（もし関係が無かったら、きっとこうなるだろうという回数）を求める
# データと期待度数との差を求める（この差が大きければ、関係ありとみなせそう）
# χ二乗値を求める
# χ二乗値をp値に変換する
# p値を解釈する　　（p値は累積確率）

# %% [markdown]
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202021-07-29%2016.04.09.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202021-07-29%2016.04.09.png)

# %% [markdown]
# p値（累積確率）のイメージ

# %% [raw]
# ex)10回コインを投げて表が出る確率
# 　　　　　　→表が1回以下であればイカサマの可能性が高い（p値が0.05を下回るため）

# %% [markdown]
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202021-07-29%2016.05.27.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202021-07-29%2016.05.27.png)
